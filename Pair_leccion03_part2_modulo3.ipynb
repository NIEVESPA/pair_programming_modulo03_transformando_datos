# %% [markdown]
# Pair EDA

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Para realizar estos ejercicios deberéis usar el conjunto de datos de world-data-2023-part1.csv.
#
# En este fichero encontraremos la siguiente información:
#
# Country: Nombre del país.
#
# Density\n(P/Km2): Densidad de población medida en personas por kilómetro cuadrado.
#
# Abbreviation: Abreviatura o código que representa al país.
#
# Agricultural Land( %): Porcentaje del área total de tierra utilizada con fines agrícolas.
#
# Land Area(Km2): Área total de tierra del país en kilómetros cuadrados.
#
# Armed Forces size: Tamaño de las fuerzas armadas en el país.
#
# Birth Rate: Número de nacimientos por cada 1,000 habitantes por año.
#
# Calling Code: Código internacional de llamada para el país.
#
# Capital/Major City: Nombre de la capital o ciudad principal.
#
# Co2-Emissions: Emisiones de dióxido de carbono en toneladas.
#
# CPI: Índice de Precios al Consumidor (IPC), una medida de la inflación y el poder adquisitivo.
#
# CPI Change (%): Cambio porcentual en el Índice de Precios al Consumidor en comparación con el año anterior.
#
# Currency-Code: Código de moneda utilizado en el país.
#
# Fertility Rate: Número promedio de hijos nacidos de una mujer durante su vida.
#
# Forested Area (%): Porcentaje del área total cubierta por bosques.
#
# Gasoline Price: Precio de la gasolina por litro en moneda local.

# %% [markdown]
# Ejercicios de exploración del conjunto de datos

# %%
df_world_data = pd.read_csv('world-data-2023_part1.csv', index_col=0)

# %% [markdown]
# Muestra las primeras 5 filas del conjunto de datos.

# %%
df_world_data.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36
# 2            3.02             0.80%         $0.28
# 3            1.27            34.00%         $1.51
# 4            5.52            46.30%         $0.97

# %% [markdown]
# Muestra las últimas 5 filas del conjunto de datos.

# %%
df_world_data.tail()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 190  Venezuela               32           VE                24.50%
# 191    Vietnam              314           VN                39.30%
# 192      Yemen               56           YE                44.60%
# 193     Zambia               25           ZM                32.10%
# 194   Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price
# 190            2.27            52.70%         $0.00
# 191            2.05            48.10%         $0.80
# 192            3.79             1.00%         $0.92
# 193            4.63            65.20%         $1.40
# 194            3.62            35.50%         $1.34

# %% [markdown]
# Muestra una muestra aleatoria de 5 filas del conjunto de datos.

# %%
df_world_data.sample(5)
# Out:
#                             Country Density\n(P/Km2) Abbreviation  \
# 80                             Iraq               93           IQ
# 58                             Fiji               49           FJ
# 159                 Solomon Islands               25           SB
# 111  Federated States of Micronesia              784           FM
# 73                     Vatican City            2,003          NaN
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 80                 21.40%        438,317           209,000       29.08
# 58                 23.30%         18,274             4,000       21.28
# 159                 3.90%         28,896               NaN       32.44
# 111                31.40%            702               NaN       22.82
# 73                    NaN              0               NaN         NaN
#
#      Calling Code Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# 80          964.0            Baghdad       190,061  119.86          0.40%
# 58          679.0               Suva         2,046   132.3          1.80%
# 159         677.0            Honiara           169  133.06          1.60%
# 111         691.0            Palikir           143   112.1          0.50%
# 73          379.0       Vatican City           NaN     NaN            NaN
#
#     Currency-Code  Fertility Rate Forested Area (%) Gasoline Price
# 80            IQD            3.67             1.90%         $0.61
# 58            FJD            2.77            55.90%         $0.82
# 159           SBD            4.40            77.90%            NaN
# 111           USD            3.05            91.90%            NaN
# 73            EUR             NaN               NaN            NaN

# %% [markdown]
# Muestra el nombre de todas las columnas en el conjunto de datos.

# %%
df_world_data.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price'],
#       dtype='object')

# %% [markdown]
# Muestra los valores únicos en la columna "Abbreviation".

# %%
df_world_data['Abbreviation'].unique()
# Out:
# array(['AF', 'AL', 'DZ', 'AD', 'AO', 'AG', 'AR', 'AM', 'AU', 'AT', 'AZ',
#        'BS', 'BH', 'BD', 'BB', 'BY', 'BE', 'BZ', 'BJ', 'BT', 'BO', 'BA',
#        'BW', 'BR', 'BN', 'BG', 'BF', 'BI', 'CI', 'CV', 'KH', 'CM', 'CA',
#        'CF', 'TD', 'CL', 'CN', 'CO', 'KM', nan, 'CR', 'HR', 'CU', 'CY',
#        'CZ', 'CD', 'DK', 'DJ', 'DM', 'DO', 'EC', 'EG', 'SV', 'GQ', 'ER',
#        'EE', 'ET', 'FJ', 'FI', 'FR', 'GA', 'GM', 'GE', 'DE', 'GH', 'GR',
#        'GD', 'GT', 'GN', 'GW', 'GY', 'HT', 'HN', 'HU', 'IS', 'IN', 'ID',
#        'IR', 'IQ', 'IL', 'IT', 'JM', 'JP', 'JO', 'KZ', 'KE', 'KI', 'KW',
#        'KG', 'LA', 'LV', 'LB', 'LS', 'LR', 'LY', 'LI', 'LT', 'LU', 'MG',
#        'MW', 'MY', 'MV', 'ML', 'MT', 'MH', 'MR', 'MU', 'MX', 'FM', 'MD',
#        'MC', 'MN', 'ME', 'MA', 'MZ', 'MM', 'NR', 'NP', 'NL', 'NZ', 'NI',
#        'NE', 'NG', 'KP', 'NO', 'OM', 'PK', 'PW', 'PA', 'PG', 'PY', 'PE',
#        'PH', 'PL', 'PT', 'QA', 'RO', 'RU', 'RW', 'KN', 'LC', 'VC', 'WS',
#        'SM', 'ST', 'SA', 'SN', 'RS', 'SC', 'SL', 'SG', 'SK', 'SI', 'SB',
#        'SO', 'ZA', 'KR', 'SS', 'ES', 'LK', 'SD', 'SR', 'SE', 'CH', 'SY',
#        'TJ', 'TZ', 'TH', 'TL', 'TG', 'TO', 'TT', 'TN', 'TR', 'TM', 'TV',
#        'UG', 'UA', 'AE', 'GB', 'US', 'UY', 'UZ', 'VU', 'VE', 'VN', 'YE',
#        'ZM', 'ZW'], dtype=object)

# %%
df_world_data['Abbreviation'].nunique()
# Out:
# 188

# %%
df_world_data['Abbreviation'].value_counts() # conteo valores unicos
# Out:
# Abbreviation
# AF    1
# AL    1
# DZ    1
# AD    1
# AO    1
#      ..
# VE    1
# VN    1
# YE    1
# ZM    1
# ZW    1
# Name: count, Length: 188, dtype: int64

# %% [markdown]
# Cuenta cuántas veces aparece cada valor único en la columna "Abbreviation".

# %%
df_world_data['Abbreviation'].size ## numero total de elementos
# Out:
# 195

# %% [markdown]
# Verifica si hay valores nulos en el conjunto de datos.

# %%
df_world_data['Abbreviation'].isna().sum()
# Out:
# np.int64(7)

# %% [markdown]
# Verifica si hay valores no nulos en el conjunto de datos.

# %%
df_world_data['Abbreviation'].notnull().sum()
# Out:
# np.int64(188)

# %% [markdown]
# Muestra información general sobre el conjunto de datos.

# %%
df_world_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                195 non-null    object
#  1   Density
# (P/Km2)        195 non-null    object
#  2   Abbreviation           188 non-null    object
#  3   Agricultural Land( %)  188 non-null    object
#  4   Land Area(Km2)         194 non-null    object
#  5   Armed Forces size      171 non-null    object
#  6   Birth Rate             189 non-null    float64
#  7   Calling Code           194 non-null    float64
#  8   Capital/Major City     192 non-null    object
#  9   Co2-Emissions          188 non-null    object
#  10  CPI                    178 non-null    object
#  11  CPI Change (%)         179 non-null    object
#  12  Currency-Code          180 non-null    object
#  13  Fertility Rate         188 non-null    float64
#  14  Forested Area (%)      188 non-null    object
#  15  Gasoline Price         175 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 25.9+ KB

# %% [markdown]
# Dimensiones y Filas
# Index: 195 entries, 0 to 194: Esto indica que el DataFrame tiene 195 filas (o "entradas"). El índice de las filas va desde el valor 0 hasta el valor 194.

# %% [markdown]
# Data columns (total 16 columns):: Esto indica que el DataFrame contiene un total de 16 columnas

# %%
Conteo de Valores No Nulos ($Non-Null Count$) Permite detectar valores faltantes. Si este número es menor que el número total de filas, hay datos ausentes en esa columna.

# %%
df_world_data.describe() ## obtenemos info con valores estadisticos(solo nos da info numerica)
# Out:
#        Birth Rate  Calling Code  Fertility Rate
# count  189.000000    194.000000      188.000000
# mean    20.214974    360.546392        2.698138
# std      9.945774    323.236419        1.282267
# min      5.900000      1.000000        0.980000
# 25%     11.300000     82.500000        1.705000
# 50%     17.950000    255.500000        2.245000
# 75%     28.750000    506.750000        3.597500
# max     46.080000   1876.000000        6.910000

# %% [markdown]
# Elimina una columna específica (por ejemplo, "Armed Forces size").

# %%
df_world_data.drop(columns='Fertility Rate') ##no se guarda en la memoria
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# 1           28,748             9,000       11.78         355.0
# 2        2,381,741           317,000       24.28         213.0
# 3              468               NaN        7.20         376.0
# 4        1,246,700           117,000       40.73         244.0
# ..             ...               ...         ...           ...
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 1               Tirana         4,536    119.05          1.40%           ALL
# 2              Algiers       150,006    151.36          2.00%           DZD
# 3     Andorra la Vella           469       NaN            NaN           EUR
# 4               Luanda        34,693    261.73         17.10%           AOA
# ..                 ...           ...       ...            ...           ...
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#     Forested Area (%) Gasoline Price
# 0               2.10%         $0.70
# 1              28.10%         $1.36
# 2               0.80%         $0.28
# 3              34.00%         $1.51
# 4              46.30%         $0.97
# ..                ...            ...
# 190            52.70%         $0.00
# 191            48.10%         $0.80
# 192             1.00%         $0.92
# 193            65.20%         $1.40
# 194            35.50%         $1.34
#
# [195 rows x 15 columns]

# %%
df_world_data.drop(columns='Fertility Rate', inplace=True)  #guardo los cambios (sale error xq he ejecutado dos veces)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_world_data.drop(columns='Fertility Rate', inplace=True)
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\Usuario\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Fertility Rate'] not found in axis"

# %%
df_world_data
# Out:
#          Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0    Afghanistan               60           AF                58.10%
# 1        Albania              105           AL                43.10%
# 2        Algeria               18           DZ                17.40%
# 3        Andorra              164           AD                40.00%
# 4         Angola               26           AO                47.50%
# ..           ...              ...          ...                   ...
# 190    Venezuela               32           VE                24.50%
# 191      Vietnam              314           VN                39.30%
# 192        Yemen               56           YE                44.60%
# 193       Zambia               25           ZM                32.10%
# 194     Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0          652,230           323,000       32.49          93.0
# 1           28,748             9,000       11.78         355.0
# 2        2,381,741           317,000       24.28         213.0
# 3              468               NaN        7.20         376.0
# 4        1,246,700           117,000       40.73         244.0
# ..             ...               ...         ...           ...
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 0                Kabul         8,672     149.9          2.30%           AFN
# 1               Tirana         4,536    119.05          1.40%           ALL
# 2              Algiers       150,006    151.36          2.00%           DZD
# 3     Andorra la Vella           469       NaN            NaN           EUR
# 4               Luanda        34,693    261.73         17.10%           AOA
# ..                 ...           ...       ...            ...           ...
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#     Forested Area (%) Gasoline Price
# 0               2.10%         $0.70
# 1              28.10%         $1.36
# 2               0.80%         $0.28
# 3              34.00%         $1.51
# 4              46.30%         $0.97
# ..                ...            ...
# 190            52.70%         $0.00
# 191            48.10%         $0.80
# 192             1.00%         $0.92
# 193            65.20%         $1.40
# 194            35.50%         $1.34
#
# [195 rows x 15 columns]

# %% [markdown]
# Selecciona las columnas numéricas del conjunto de datos y muestra sus estadísticas descriptivas básicas. para esto tendréis que usar el método '.describe().

# %%
df_world_data.select_dtypes(include=['int','float'])
# Out:
#      Birth Rate  Calling Code
# 0         32.49          93.0
# 1         11.78         355.0
# 2         24.28         213.0
# 3          7.20         376.0
# 4         40.73         244.0
# ..          ...           ...
# 190       17.88          58.0
# 191       16.75          84.0
# 192       30.45         967.0
# 193       36.19         260.0
# 194       30.68         263.0
#
# [195 rows x 2 columns]

# %%
df_world_data.select_dtypes(include=['int','float']).describe()
# Out:
#        Birth Rate  Calling Code
# count  189.000000    194.000000
# mean    20.214974    360.546392
# std      9.945774    323.236419
# min      5.900000      1.000000
# 25%     11.300000     82.500000
# 50%     17.950000    255.500000
# 75%     28.750000    506.750000
# max     46.080000   1876.000000

# %%
df_world_data.select_dtypes(include=['int','float']).describe().T
# Out:
#               count        mean         std  min   25%     50%     75%  \
# Birth Rate    189.0   20.214974    9.945774  5.9  11.3   17.95   28.75
# Calling Code  194.0  360.546392  323.236419  1.0  82.5  255.50  506.75
#
#                   max
# Birth Rate      46.08
# Calling Code  1876.00
